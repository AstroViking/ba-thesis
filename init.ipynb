# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook. You can put custom code you want us to run every time we setup your environment in here. No need to put `!pip install`s here though, we already save those automatically. If you want to learn more about how this works, [check out our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# Install your packages apart from blacklisted packages that interfere with Deepnote. Installing those would break your environment.
# !if test -f requirements.txt; then pip install $(sed '/jedi/d;/jupyter/d;' ./requirements.txt); fi

# Install other necessary packages and restoring your environment from last time
# !if test -f .deepnote/requirements.txt; then pip install  $(sed '/jupyter/d' .deepnote/requirements.txt); fi

# %%
# !./scripts/install-tools.sh
